#
#         sensor16    sensor17    sensor18    sensor19    sensor20    sensor21  \
# 0     120.263026  103.388247  129.357139   71.203975  115.805224  109.152430
# 1     116.778120   97.205434  125.803717   76.741519  121.598143  119.721098
# 2     129.622060  103.230353  129.124964   76.562924  116.718953  110.254270
# 3     121.699406  100.480400  133.278976   65.766647  116.599690  116.804736
# 4     116.536543   94.081706  121.844260   81.466041  116.253564  111.156953
# ...          ...         ...         ...         ...         ...         ...
# 2438  113.918293  134.921455  110.990175  104.316390   79.249174  141.720423
# 2439  100.108167  134.707527  114.942587  101.871073   80.963927  144.794605
# 2440  117.353452  127.704866  114.665986  103.019962   75.730431  146.675291
# 2441  116.983920  131.136589  108.265248  103.855132   73.362541  141.165501
# 2442  104.996047  125.239858  113.122793  100.201067   72.254354  130.785799
#
#         sensor22    sensor23    sensor24
# 0     149.814185   95.443583  117.297459
# 1     138.885345   87.733074  127.166064
# 2     136.978924   94.450501  124.100148
# 3     138.952326   92.785178  133.108180
# 4     137.966520   93.099678  117.250950
# ...          ...         ...         ...
# 2438  120.617128  121.394314   91.640711
# 2439  120.054951  117.094137   94.807750
# 2440  117.336371  121.081680   94.455564
# 2441  123.007369  123.280110  102.306949
# 2442  118.246552  114.262466  108.760435
#
# [2443 rows x 24 columns]

# %%
y
# Out:
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# # Define models

# %%
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# %% [markdown]
# # Define k-fold cross-validation

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Create empty dictionary to store the results

# %%
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# %% [markdown]
# # Train and evaluate each model using k-fold cross-validation

# %%
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 14.77
# Fold 1 - Mean Absolute Error (MAE): 3.03
# Fold 1 - Root Mean Squared Error (RMSE): 3.84
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 15.40
# Fold 2 - Mean Absolute Error (MAE): 3.15
# Fold 2 - Root Mean Squared Error (RMSE): 3.92
# Fold 2 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 14.64
# Fold 3 - Mean Absolute Error (MAE): 3.06
# Fold 3 - Root Mean Squared Error (RMSE): 3.83
# Fold 3 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 15.71
# Fold 4 - Mean Absolute Error (MAE): 3.13
# Fold 4 - Root Mean Squared Error (RMSE): 3.96
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 14.56
# Fold 5 - Mean Absolute Error (MAE): 3.06
# Fold 5 - Root Mean Squared Error (RMSE): 3.82
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 15.02
# Mean - Mean Absolute Error (MAE): 3.09
# Mean - Root Mean Squared Error (RMSE): 3.87
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 96.75
# Fold 1 - Mean Absolute Error (MAE): 6.27
# Fold 1 - Root Mean Squared Error (RMSE): 9.84
# Fold 1 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 96.03
# Fold 2 - Mean Absolute Error (MAE): 6.31
# Fold 2 - Root Mean Squared Error (RMSE): 9.80
# Fold 2 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 99.72
# Fold 3 - Mean Absolute Error (MAE): 6.33
# Fold 3 - Root Mean Squared Error (RMSE): 9.99
# Fold 3 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 93.28
# Fold 4 - Mean Absolute Error (MAE): 6.17
# Fold 4 - Root Mean Squared Error (RMSE): 9.66
# Fold 4 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 103.62
# Fold 5 - Mean Absolute Error (MAE): 6.56
# Fold 5 - Root Mean Squared Error (RMSE): 10.18
# Fold 5 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 97.88
# Mean - Mean Absolute Error (MAE): 6.33
# Mean - Root Mean Squared Error (RMSE): 9.89
# Mean - Time taken: 0.03 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 22.03
# Fold 1 - Mean Absolute Error (MAE): 3.68
# Fold 1 - Root Mean Squared Error (RMSE): 4.69
# Fold 1 - Time taken: 1.43 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 21.33
# Fold 2 - Mean Absolute Error (MAE): 3.68
# Fold 2 - Root Mean Squared Error (RMSE): 4.62
# Fold 2 - Time taken: 1.38 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 25.76
# Fold 3 - Mean Absolute Error (MAE): 3.89
# Fold 3 - Root Mean Squared Error (RMSE): 5.08
# Fold 3 - Time taken: 1.34 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 23.25
# Fold 4 - Mean Absolute Error (MAE): 3.78
# Fold 4 - Root Mean Squared Error (RMSE): 4.82
# Fold 4 - Time taken: 1.34 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 26.00
# Fold 5 - Mean Absolute Error (MAE): 3.95
# Fold 5 - Root Mean Squared Error (RMSE): 5.10
# Fold 5 - Time taken: 1.34 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 23.67
# Mean - Mean Absolute Error (MAE): 3.79
# Mean - Root Mean Squared Error (RMSE): 4.86
# Mean - Time taken: 1.37 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 9.72
# Fold 1 - Mean Absolute Error (MAE): 2.03
# Fold 1 - Root Mean Squared Error (RMSE): 3.12
# Fold 1 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 11.28
# Fold 2 - Mean Absolute Error (MAE): 2.23
# Fold 2 - Root Mean Squared Error (RMSE): 3.36
# Fold 2 - Time taken: 0.03 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 10.03
# Fold 3 - Mean Absolute Error (MAE): 2.10
# Fold 3 - Root Mean Squared Error (RMSE): 3.17
# Fold 3 - Time taken: 0.03 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 10.31
# Fold 4 - Mean Absolute Error (MAE): 2.16
# Fold 4 - Root Mean Squared Error (RMSE): 3.21
# Fold 4 - Time taken: 0.03 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 9.91
# Fold 5 - Mean Absolute Error (MAE): 2.08
# Fold 5 - Root Mean Squared Error (RMSE): 3.15
# Fold 5 - Time taken: 0.03 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 10.25
# Mean - Mean Absolute Error (MAE): 2.12
# Mean - Root Mean Squared Error (RMSE): 3.20
# Mean - Time taken: 0.03 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 25.54
# Fold 1 - Mean Absolute Error (MAE): 3.67
# Fold 1 - Root Mean Squared Error (RMSE): 5.05
# Fold 1 - Time taken: 0.45 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 23.92
# Fold 2 - Mean Absolute Error (MAE): 3.64
# Fold 2 - Root Mean Squared Error (RMSE): 4.89
# Fold 2 - Time taken: 0.57 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 25.30
# Fold 3 - Mean Absolute Error (MAE): 3.61
# Fold 3 - Root Mean Squared Error (RMSE): 5.03
# Fold 3 - Time taken: 0.34 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 26.85
# Fold 4 - Mean Absolute Error (MAE): 3.78
# Fold 4 - Root Mean Squared Error (RMSE): 5.18
# Fold 4 - Time taken: 0.32 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 25.89
# Fold 5 - Mean Absolute Error (MAE): 3.69
# Fold 5 - Root Mean Squared Error (RMSE): 5.09
# Fold 5 - Time taken: 0.33 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 25.50
# Mean - Mean Absolute Error (MAE): 3.68
# Mean - Root Mean Squared Error (RMSE): 5.05
# Mean - Time taken: 0.40 seconds

# %% [markdown]
# # Saving the Mean results to an Excel file

# %%
# Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

# Filter the dataframe to include only the mean values
mean_results_df = results_df[results_df["Fold"] == "Mean"]

# Save the mean results to an Excel file
mean_results_df.to_excel("(1-24) Sensors PL_model_1_Scattered1_Reg1 Results.xlsx", index=False)
