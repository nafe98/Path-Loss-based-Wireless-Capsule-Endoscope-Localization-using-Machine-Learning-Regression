# 2441  139.564043  109.141995  106.936201   78.218026  144.561741  141.507291
# 2442  132.013398  115.430773  105.461899   71.804618  151.624598  143.982949
#
#          sensor7     sensor8
# 0     103.508252  125.193887
# 1     106.645699  137.372609
# 2     103.789337  135.667714
# 3     102.460744  129.928887
# 4     116.786233  139.061346
# ...          ...         ...
# 2438  123.942335  108.196626
# 2439  136.835759  113.267986
# 2440  129.875574  120.944104
# 2441  125.361425  123.071554
# 2442  127.958184  113.784393
#
# [2443 rows x 8 columns]

# %% [markdown]
# # Importing Libraries

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

import time
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Converting Numpy Arrays to Pandas DataFrames for Sensor and Position Data

# %%
X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# %%
X
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     101.870132  134.252574   72.801390  108.446568  130.203502  150.760073
# 1     101.656974  133.421922   76.037698  115.578180  124.237134  144.797812
# 2     102.889598  140.640194   71.553137  106.871465  123.654012  148.446127
# 3     100.508164  130.788193   73.179060  122.566756  128.558120  144.121205
# 4     104.073940  127.217426   69.730286  115.690253  120.920018  148.666096
# ...          ...         ...         ...         ...         ...         ...
# 2438  126.520010  110.917507  102.822108   62.853700  149.747652  127.099840
# 2439  122.656116  114.785269   98.718438   76.449249  152.660776  140.174139
# 2440  126.597748  119.491178  105.538634   75.394449  145.766322  143.595590
# 2441  139.564043  109.141995  106.936201   78.218026  144.561741  141.507291
# 2442  132.013398  115.430773  105.461899   71.804618  151.624598  143.982949
#
#          sensor7     sensor8
# 0     103.508252  125.193887
# 1     106.645699  137.372609
# 2     103.789337  135.667714
# 3     102.460744  129.928887
# 4     116.786233  139.061346
# ...          ...         ...
# 2438  123.942335  108.196626
# 2439  136.835759  113.267986
# 2440  129.875574  120.944104
# 2441  125.361425  123.071554
# 2442  127.958184  113.784393
#
# [2443 rows x 8 columns]

# %%
y
# Out:
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# # Define models

# %%
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# %% [markdown]
# # Define k-fold cross-validation

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Create empty dictionary to store the results

# %%
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# %% [markdown]
# # Train and evaluate each model using k-fold cross-validation

# %%
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 42.62
# Fold 1 - Mean Absolute Error (MAE): 5.20
# Fold 1 - Root Mean Squared Error (RMSE): 6.53
# Fold 1 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 41.90
# Fold 2 - Mean Absolute Error (MAE): 5.17
# Fold 2 - Root Mean Squared Error (RMSE): 6.47
# Fold 2 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 41.29
# Fold 3 - Mean Absolute Error (MAE): 5.19
# Fold 3 - Root Mean Squared Error (RMSE): 6.43
# Fold 3 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 39.62
# Fold 4 - Mean Absolute Error (MAE): 5.07
# Fold 4 - Root Mean Squared Error (RMSE): 6.29
# Fold 4 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 43.91
# Fold 5 - Mean Absolute Error (MAE): 5.32
# Fold 5 - Root Mean Squared Error (RMSE): 6.63
# Fold 5 - Time taken: 0.00 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 41.87
# Mean - Mean Absolute Error (MAE): 5.19
# Mean - Root Mean Squared Error (RMSE): 6.47
# Mean - Time taken: 0.00 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 112.10
# Fold 1 - Mean Absolute Error (MAE): 6.91
# Fold 1 - Root Mean Squared Error (RMSE): 10.59
# Fold 1 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 102.37
# Fold 2 - Mean Absolute Error (MAE): 6.45
# Fold 2 - Root Mean Squared Error (RMSE): 10.12
# Fold 2 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 99.93
# Fold 3 - Mean Absolute Error (MAE): 6.55
# Fold 3 - Root Mean Squared Error (RMSE): 10.00
# Fold 3 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 101.85
# Fold 4 - Mean Absolute Error (MAE): 6.71
# Fold 4 - Root Mean Squared Error (RMSE): 10.09
# Fold 4 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 104.24
# Fold 5 - Mean Absolute Error (MAE): 6.62
# Fold 5 - Root Mean Squared Error (RMSE): 10.21
# Fold 5 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 104.09
# Mean - Mean Absolute Error (MAE): 6.65
# Mean - Root Mean Squared Error (RMSE): 10.20
# Mean - Time taken: 0.01 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 39.23
# Fold 1 - Mean Absolute Error (MAE): 4.65
# Fold 1 - Root Mean Squared Error (RMSE): 6.26
# Fold 1 - Time taken: 0.58 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 40.40
# Fold 2 - Mean Absolute Error (MAE): 4.72
# Fold 2 - Root Mean Squared Error (RMSE): 6.36
# Fold 2 - Time taken: 0.57 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 38.89
# Fold 3 - Mean Absolute Error (MAE): 4.66
# Fold 3 - Root Mean Squared Error (RMSE): 6.24
# Fold 3 - Time taken: 0.58 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 39.27
# Fold 4 - Mean Absolute Error (MAE): 4.75
# Fold 4 - Root Mean Squared Error (RMSE): 6.27
# Fold 4 - Time taken: 0.57 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 39.95
# Fold 5 - Mean Absolute Error (MAE): 4.78
# Fold 5 - Root Mean Squared Error (RMSE): 6.32
# Fold 5 - Time taken: 0.58 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 39.55
# Mean - Mean Absolute Error (MAE): 4.71
# Mean - Root Mean Squared Error (RMSE): 6.29
# Mean - Time taken: 0.58 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 31.30
# Fold 1 - Mean Absolute Error (MAE): 3.78
# Fold 1 - Root Mean Squared Error (RMSE): 5.59
# Fold 1 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 31.80
# Fold 2 - Mean Absolute Error (MAE): 3.84
# Fold 2 - Root Mean Squared Error (RMSE): 5.64
# Fold 2 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 33.44
# Fold 3 - Mean Absolute Error (MAE): 3.98
# Fold 3 - Root Mean Squared Error (RMSE): 5.78
# Fold 3 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 30.32
# Fold 4 - Mean Absolute Error (MAE): 3.82
# Fold 4 - Root Mean Squared Error (RMSE): 5.51
# Fold 4 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 34.75
# Fold 5 - Mean Absolute Error (MAE): 4.00
# Fold 5 - Root Mean Squared Error (RMSE): 5.89
# Fold 5 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 32.32
# Mean - Mean Absolute Error (MAE): 3.88
# Mean - Root Mean Squared Error (RMSE): 5.68
# Mean - Time taken: 0.01 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 44.08
# Fold 1 - Mean Absolute Error (MAE): 4.87
# Fold 1 - Root Mean Squared Error (RMSE): 6.64
# Fold 1 - Time taken: 0.24 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 40.45
# Fold 2 - Mean Absolute Error (MAE): 4.71
# Fold 2 - Root Mean Squared Error (RMSE): 6.36
# Fold 2 - Time taken: 0.21 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 45.87
# Fold 3 - Mean Absolute Error (MAE): 4.93
# Fold 3 - Root Mean Squared Error (RMSE): 6.77
# Fold 3 - Time taken: 0.21 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 43.20
# Fold 4 - Mean Absolute Error (MAE): 4.86
# Fold 4 - Root Mean Squared Error (RMSE): 6.57
# Fold 4 - Time taken: 0.23 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 45.07
# Fold 5 - Mean Absolute Error (MAE): 4.97
# Fold 5 - Root Mean Squared Error (RMSE): 6.71
# Fold 5 - Time taken: 0.23 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 43.73
# Mean - Mean Absolute Error (MAE): 4.87
# Mean - Root Mean Squared Error (RMSE): 6.61
# Mean - Time taken: 0.23 seconds

# %% [markdown]
# # Saving the Mean results to an Excel file

# %%
# Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

# Filter the dataframe to include only the mean values
mean_results_df = results_df[results_df["Fold"] == "Mean"]

# Save the mean results to an Excel file
mean_results_df.to_excel("(1-8) Sensors PL_model_1_Scattered_iReg3 results.xlsx", index=False)
